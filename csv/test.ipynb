# %%
import pandas as pd

# %%
df = pd.read_csv("asd_full.csv")

# %%
df[df["affinity_type"] == "kd"].count()
# Out:
# dataset                  7007
# heavy_sequence           7007
# light_sequence           6849
# scfv                     7007
# affinity_type            7007
# affinity                 6988
# antigen_sequence         7007
# confidence               7007
# nanobody                 7007
# metadata                 7007
# processed_measurement    6988
# dtype: int64
